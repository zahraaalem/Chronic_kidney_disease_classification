# %%
from tkinter import *
root = Tk()
root.title("Home")
root.geometry("800x650")
root.resizable(False,False)
root.config(bg="#e4c5c5")


def GetValues():
    global age
    global bp
    global sg
    global al
    global su
    global rbc
    global pc
    global pcc
    global ba
    global bgr
    global bu
    global sc
    global sod
    global pot
    global hemo
    global pcv
    global wc
    global rc
    global htn
    global dm
    global cad
    global appet
    global pe
    global ane
    
    
    age = float(eAge.get())
    bp = float(ePressure.get())
    sg = float(eSpecific_gravity.get())
    al = float(eAlbumin.get())
    su = float(eSugar.get())
    rbc = float(eRed_blood.get())
    pc = float(ePus_cell.get())
    pcc = float(ePus_Cell_Clumps.get())
    ba = float(eBacteria.get())
    bgr = float(eGlucose.get())
    bu = float(eUrea.get())
    sc = float(eSerum.get())
    sod = float(eSodium.get())
    pot = float(ePotassium.get())
    hemo = float(eHemoglobin.get())
    pcv = float(ePacked.get())
    wc = float(eWhite_Blood.get())
    rc = float(eRed_Blood.get())
    htn = float(eHypertension.get())
    dm = float(eDiabetes_Mellitus.get())
    cad = float(eCoronary_Artery_Disease.get())
    appet = float(eAppetite.get())
    pe = float(ePedal_Edema.get())
    ane = float(eAnemia.get())

    import joblib as jb
    model = jb.load('C:/Users/Pro/Desktop/kidmodel.sav')
    
    
    import pandas as pd
    DF1 = pd.DataFrame(columns=['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba',
       'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm',
       'cad', 'appet', 'pe', 'ane'])
    
   
    DF1.loc[0,'age']= age
    
    DF1.loc[0,'bp']= bp
    
    DF1.loc[0,'sg']= sg
    
    DF1.loc[0,'al']= al
    
    DF1.loc[0,'su']= su
    
    DF1.loc[0,'rbc']=rbc
    
    DF1.loc[0,'pc']= pc
    
    DF1.loc[0,'pcc']= pcc
    
    DF1.loc[0,'ba']= ba
    
    DF1.loc[0,'bgr']= bgr
    
    DF1.loc[0,'bu']= bu
    
    DF1.loc[0,'sc']= sc
    
    DF1.loc[0,'sod']= sod
    
    DF1.loc[0,'pot']= pot
    
    DF1.loc[0,'hemo']= hemo
    
    DF1.loc[0,'pcv']= pcv
    
    DF1.loc[0,'wc']= wc
    
    DF1.loc[0,'rc']= rc
    
    DF1.loc[0,'htn']= htn
    
    DF1.loc[0,'dm']= dm
    
    DF1.loc[0,'cad']= cad
    
    DF1.loc[0,'appet']= appet
    
    DF1.loc[0,'pe']= pe
    
    DF1.loc[0,'ane']= ane
    
    
    res = model.predict(DF1.values)
    
    if res == [1]:
        final = Label(root, text = "You have Chronic kidney disease", bg = 'cyan')
    else :
        final = Label(root, text = "You don't have Chronic kidney disease", bg = 'cyan')
    
    final.place(x=300,y = 600)

    
    
    

    





Label_Coronary=Label(root, text="Welcome to our Application",bg="#e4c5c5",font=("Arial", 25))
Label_Coronary.place(x=200,y=20)

Label_Coronary=Label(root, text="Our Application is used to diagnose ",bg="#e4c5c5",font=("Arial", 15))
Label_Coronary.place(x=250,y=70)

Label_Coronary=Label(root, text="Kidney Disease",bg="#e4c5c5",font=("Arial", 15))
Label_Coronary.place(x=330,y=100)





lAge=Label(root, text="Age",bg="#e4c5c5")
lAge.place(x=2,y=197)
eAge=Entry(root,font=("Arial", 12) , bg="#d5d5d5")
eAge.place(x=130,y=197)


lPressure=Label(root, text="Blood Pressure",bg="#e4c5c5")
lPressure.place(x=2,y=217)
ePressure=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePressure.place(x=130,y=217)


lGlucose=Label(root, text="Blood Glucose Random",bg="#e4c5c5")
lGlucose.place(x=2,y=237)
eGlucose=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eGlucose.place(x=130,y=237)


lUrea=Label(root, text="Blood Urea",bg="#e4c5c5")
lUrea.place(x=2,y=257)
eUrea=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eUrea.place(x=130,y=257)

lSerum=Label(root, text="Serum Creatinine",bg="#e4c5c5")
lSerum.place(x=2,y=277)    
eSerum=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eSerum.place(x=130,y=277)    

lPotassium=Label(root, text="Potassium",bg="#e4c5c5")
lPotassium.place(x=2,y=297)
ePotassium=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePotassium.place(x=130,y=297)

lHemoglobin=Label(root, text="Hemoglobin",bg="#e4c5c5")
lHemoglobin.place(x=2,y=317)
eHemoglobin=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eHemoglobin.place(x=130,y=317)

lPacked=Label(root, text="Packed Cell Volume",bg="#e4c5c5")
lPacked.place(x=2,y=337)
ePacked=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePacked.place(x=130,y=337)
    

lWhite_Blood=Label(root, text="White Blood Cell Count",bg="#e4c5c5")
lWhite_Blood.place(x=2,y=357)
eWhite_Blood=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eWhite_Blood.place(x=130,y=357)



lRed_Blood=Label(root, text="Red Blood Cell Count",bg="#e4c5c5")
lRed_Blood.place(x=2,y=377)
eRed_Blood=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eRed_Blood.place(x=130,y=377)

lSodium=Label(root, text="Sodium",bg="#e4c5c5")
lSodium.place(x=2,y=397)
eSodium=Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eSodium.place(x=130,y=397)










l1=Label(root, text="⚠️If the value is Normal, Present, Yes or Good Enter '1'⚠️",bg="#e4c5c5",font=("Arial", 12))
l1.place(x=390,y=150)
l1=Label(root, text="Else Enter '0' ",bg="#e4c5c5",font=("Arial", 12))
l1.place(x=500,y=170)



label_Specifi_Gravity=Label(root, text="Specific Gravity",bg="#e4c5c5")
label_Specifi_Gravity.place(x=400,y=197)
eSpecific_gravity = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eSpecific_gravity.place(x=550,y=197)

label_Sugar=Label(root, text="sugar",bg="#e4c5c5")
label_Sugar.place(x=400,y=217)
eSugar = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eSugar.place(x=550,y=217)




label_Albumin=Label(root, text="albumin",bg="#e4c5c5")
label_Albumin.place(x=400,y=237)
eAlbumin = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eAlbumin.place(x=550,y=237)

Label_red_blood=Label(root, text=" red blood cells",bg="#e4c5c5")
Label_red_blood.place(x=400,y=257)
eRed_blood = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eRed_blood.place(x=550,y=257)

Label_Pus_Cell=Label(root, text="Pus Cell",bg="#e4c5c5")
Label_Pus_Cell.place(x=400,y=277)
ePus_cell = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePus_cell.place(x=550,y=277)


Label_Pus_Cell_Clumps=Label(root, text="Pus Cell Clumps",bg="#e4c5c5")
Label_Pus_Cell_Clumps.place(x=400,y=297)
ePus_Cell_Clumps = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePus_Cell_Clumps.place(x=550,y=297)

Label_Bacteria=Label(root, text="Bacteria",bg="#e4c5c5")
Label_Bacteria.place(x=400,y=317)
eBacteria= Entry(root,font=("Arial", 12), bg="#d5d5d5")
eBacteria.place(x=550,y=317)

Label_Hypertension=Label(root, text="Hypertension",bg="#e4c5c5")
Label_Hypertension.place(x=400,y=337)
eHypertension = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eHypertension.place(x=550,y=337)

Label_Diabetes=Label(root, text="Diabetes Mellitus",bg="#e4c5c5")
Label_Diabetes.place(x=400,y=357)
eDiabetes_Mellitus = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eDiabetes_Mellitus.place(x=550,y=357)

Label_Coronary=Label(root, text="Coronary Artery Disease",bg="#e4c5c5")
Label_Coronary.place(x=400,y=377)
eCoronary_Artery_Disease= Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eCoronary_Artery_Disease.place(x=550,y=377)

Label_Pedal_Edema=Label(root, text="Pedal Edema",bg="#e4c5c5")
Label_Pedal_Edema.place(x=400,y=397)
ePedal_Edema = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
ePedal_Edema.place(x=550,y=397)

Label_Anemia=Label(root, text="Anemia",bg="#e4c5c5")
Label_Anemia.place(x=400,y=417)
eAnemia = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eAnemia.place(x=550,y=417)

Label_Appetite=Label(root, text="Appetite",bg="#e4c5c5")
Label_Appetite.place(x=400,y=437)
eAppetite = Entry(root,font=("Arial", 12),  bg="#d5d5d5")
eAppetite.place(x=550,y=437)



bButton=Button(root,text="Diagnose", bg="#03bfe7",fg="white",height=1 , width=10 ,font=("Arial", 12),command = GetValues)
bButton.place(x=100,y=600)


root.mainloop()
